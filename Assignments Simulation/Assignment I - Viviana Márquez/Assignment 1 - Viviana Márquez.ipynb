# %% [markdown]
# <img src="http://orientacion.universia.net.co/imgs2011/imagenes/logo-header-konradlorenz.png">
# # Simulation
# ### Assignment 1
# <b>Name:</b> Viviana Márquez<br>
# <b>Code:</b> 614132005<br>
# <b>Date:</b> Saturday, February 11th, 2016<br>
# <hr>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib as mpl
import seaborn as sns

# %%
with open('Data_Simulation.txt', 'r') as f:
    lines = f.readlines()

yaxis = []    
for line in lines:
    yaxis.append(float(line))
    
max_item = max(yaxis)
min_item = min(yaxis)
xaxis = list(range(0,len(yaxis)))

mpl.rc("figure", figsize=(16, 8))
sns.set_palette("muted") #husl

# %%
plt.xlim(0,len(yaxis))
plt.ylim(min_item,max_item)
plt.plot(xaxis,yaxis)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Data Plot')
plt.show()

# %% [markdown]
# ### 1. Data
# 2). Answer the following questions:<BR>
# ---a). What statistical tools could you use to analyse them?
# <font color="blue">First, I am going to take a quick look at the data. I will use the distplot() function for this purpose. This function draws a histogram of the data and estimates the probaility distribution.</font>

# %%
data = yaxis
sns.distplot(data);
# Out:
# /Users/vivianamarquez/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### 1. Data
# 2). Answer the following questions:<BR>
# ---b). Do the data follow any type of statistical distribution?<BR>
# <font color="blue">The data is not skewed to the right nor to the left. Also, it is not bimodal nor multimodal. It seems to follow normal distribution closely.</font>

# %%
df = pd.DataFrame(data)
df = df.sample(frac=0.1, replace=True)
#I will take only 10 percent of the data in order to avoid great distress to my old computer.

# %%
sns.distplot(df, kde=False, fit=stats.norm);

# %%
sns.distplot(df, kde=False, fit=stats.weibull_max);
# Out:
# /Users/vivianamarquez/anaconda/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py:1598: RuntimeWarning: divide by zero encountered in power
#   return c*pow(-x, c-1)*exp(-pow(-x, c))

# %%
sns.distplot(df, kde=False, fit=stats.expon);

# %% [markdown]
# ### 1. Data
# 2). Answer the following questions:<BR>
# ---c). What can you say about the data?<BR>
# <font color="blue">As we can see by the three graphs above, the data best fits normal (Gaussian) distribution. Because of this, we can tell that the data tends to be around a central value and is symmetric.</font>

# %% [markdown]
# ### 2. Random numbers
#
# (10 Points) Explain an algorithm for generating random numbers and provide an example.
# <br><br>
# <font color="blue">In general, in order to be able to generate a random number, we need an initial number that goes through an algorithm that outputs another number. Ideally, this algorithm should have an equal chance of giving any value over a given range. With this in mind, we can see that the hardest thing is not the algotithm itself, but rather the concept of an initial number, often refered as "seed". <br><br>
#
# In my algothim, I will use the computer's timestamp of milliseconds as a seed. I choose this because of its high accuracy (there will be a new millisecond, even if the program is restarted in the same second).<br><br>
#
# First, I will capture <b>millis1</b>. I will use this number two times in my algorithm. The first time, I will take its last digit to generate a system pause, and then I will capture a second number that I will call <b>millis2</b>. The last digit of this new number will be used to generate the requested random number in this way: <b>random = millis1 % lastdigit_millis2</b>. As a precaution, I also inserted a small piece of code where I make sure the last digit of <b>millis2</b> is not zero (to avoid divison by 0). </font>
#
# <font color="blue">Example (Algorithm): </font>
# https://github.com/vivianamarquez/Simulation-2017-I/blob/master/02-11-17/Random

# %% [markdown]
# ### 3. git Repository
#
# (20 Points) Create a git repository on https://github.com or https://bitbucket.org/ and made a commit with a code written in any programming language that calculates Fibonacci numbers. The solution of this question is the URL of your repository.
# <br>
# <font color="blue">Solution: </font>
# https://github.com/vivianamarquez/Simulation-2017-I/blob/master/02-11-17/Fibonnacci
